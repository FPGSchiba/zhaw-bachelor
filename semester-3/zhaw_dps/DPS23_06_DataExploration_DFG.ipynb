# %% [markdown]
# # Introduction to Process Mining with PM4PY
# Code is partially copied from this tutorial: https://medium.com/@c3_62722/process-mining-with-python-tutorial-a-healthcare-application-part-1-ae02027a050

# %%
#!pip install update pm4py==2.7.8

# %%
import pm4py
# how pm4py version
print(pm4py.__version__)
# Out:
# 2.7.8

# %%
import pandas as pd
import numpy as np
from datetime import date
from IPython.display import Markdown, display
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fn = 'ArtificialPatientTreatment.csv'
events = pd.read_csv(fn)

events.columns = ['patient', 'action', 'resource', 'datetime']
events['datetime'] = pd.to_datetime(events['datetime'])
events.head()
# Out:
#      patient           action      resource            datetime
# 0  patient 0    First consult      Dr. Anna 2017-01-02 11:40:11
# 1  patient 0       Blood test           Lab 2017-01-02 12:47:33
# 2  patient 0    Physical test   Nurse Jesse 2017-01-02 12:53:50
# 3  patient 0   Second consult      Dr. Anna 2017-01-02 16:21:06
# 4  patient 0          Surgery   Dr. Charlie 2017-01-05 13:23:09

# %%
print('{} has {} rows and {} columns.'.format(fn, events.shape[0], events.shape[1]))
# Out:
# ArtificialPatientTreatment.csv has 690 rows and 4 columns.

# %% [markdown]
# ### How many events per case?

# %%
events['patient'].value_counts().value_counts().plot(kind='bar')
plt.xlabel('Number of actions per patient')
plt.ylabel('Number of patients')
# Out:
# Text(0, 0.5, 'Number of patients')

# %%
events['patient'].value_counts().value_counts()
# Out:
# count
# 7    90
# 6    10
# Name: count, dtype: int64

# %% [markdown]
# ### Action occurrences

# %%
events['action'].value_counts().plot(kind='bar')
plt.xlabel('action')
plt.ylabel('number of occurrences')
# Out:
# Text(0, 0.5, 'number of occurrences')

# %% [markdown]
# # Process Mining

# %%
#!pip install pm4py --user
from pm4py.objects.conversion.log import converter as log_converter
# from pm4py.objects.log.importer.xes import importer as xes_importer

# process mining 
# from pm4py.algo.discovery.alpha import algorithm as alpha_miner
# from pm4py.algo.discovery.inductive import algorithm as inductive_miner
# from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner
from pm4py.algo.discovery.dfg import algorithm as dfg_discovery
from pm4py.algo.discovery.footprints import algorithm as footprints_discovery


# viz
# from pm4py.visualization.petri_net import visualizer as pn_visualizer
from pm4py.visualization.footprints import visualizer as fp_visualizer
# from pm4py.visualization.transition_system import visualizer as ts_visualizer
# from pm4py.visualization.process_tree import visualizer as pt_visualizer
# from pm4py.visualization.heuristics_net import visualizer as hn_visualizer
from pm4py.visualization.dfg import visualizer as dfg_visualization

# misc 
# from pm4py.objects.petri_net.utils import reachability_graph
# from pm4py.objects.conversion.process_tree import converter as pt_converter

import pm4py

# %%
eventlog = events.copy()
### Specify which columns correspond to case (case:concept:name), 
###event (concept:name) and timestamp (time:timestamp) - rename columns in accordance
###with pm4py

eventlog.rename(columns={'datetime': 'time:timestamp', 'patient': 'case:concept:name', 'action': 'concept:name', 'resource': 'org:resource'}, inplace=True)

## Convert to log format
log = log_converter.apply(eventlog)

# %% [markdown]
# ### Log Exploration

# %%
# start activities
log_start = pm4py.get_start_activities(log)
log_start
# Out:
# /Users/schiba/miniforge3/envs/zhaw-dps/lib/python3.11/site-packages/pm4py/utils.py:503: UserWarning: the EventLog class has been deprecated and will be removed in a future release.
#   warnings.warn("the EventLog class has been deprecated and will be removed in a future release.")
# {' First consult': 100}

# %%
# end activities
end_activities = pm4py.get_end_activities(log)
end_activities
# Out:
# {' Final consult': 100}

# %%
# traces
variants = pm4py.get_variants_as_tuples(log)
print(len(variants))
variants
# Out:
# 15
# {(' First consult',
#   ' Blood test',
#   ' Physical test',
#   ' Second consult',
#   ' Surgery',
#   ' Final consult'): [{'attributes': {'concept:name': 'patient 0'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-01-02 11:40:11')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-01-09 08:29:28')}]},
#   {'attributes': {'concept:name': 'patient 95'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-15 09:15:08')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-26 10:19:34')}]}],
#  (' First consult',
#   ' Physical test',
#   ' Blood test',
#   ' X-ray scan',
#   ' Second consult',
#   ' Medicine',
#   ' Final consult'): [{'attributes': {'concept:name': 'patient 1'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-01-02 12:50:35')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-01-06 16:49:21')}]},
#   {'attributes': {'concept:name': 'patient 10'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-01-17 14:13:17')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-01-30 11:19:19')}]},
#   {'attributes': {'concept:name': 'patient 16'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-01-26 16:47:05')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-02-07 08:55:43')}]},
#   {'attributes': {'concept:name': 'patient 45'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-03-07 13:06:04')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-03-20 12:32:46')}]},
#   {'attributes': {'concept:name': 'patient 46'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-03-08 10:07:29')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-03-20 11:10:16')}]},
#   {'attributes': {'concept:name': 'patient 67'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-04-06 10:49:36')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-04-17 13:00:11')}]},
#   {'attributes': {'concept:name': 'patient 73'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-04-13 14:27:05')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-04-24 13:17:24')}]},
#   {'attributes': {'concept:name': 'patient 74'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-04-17 12:47:57')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-04-26 08:50:55')}]},
#   {'attributes': {'concept:name': 'patient 85'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-04-28 16:09:52')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-05-10 12:07:20')}]},
#   {'attributes': {'concept:name': 'patient 90'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-08 15:30:08')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-05-11 16:34:28')}]}],
#  (' First consult',
#   ' Physical test',
#   ' X-ray scan',
#   ' Blood test',
#   ' Second consult',
#   ' Medicine',
#   ' Final consult'): [{'attributes': {'concept:name': 'patient 2'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-01-04 10:02:49')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-01-17 11:54:48')}]},
#   {'attributes': {'concept:name': 'patient 7'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-01-12 17:58:50')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-01-20 14:11:01')}]},
#   {'attributes': {'concept:name': 'patient 17'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-01-27 12:02:23')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-02-09 12:46:25')}]},
#   {'attributes': {'concept:name': 'patient 49'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-03-13 10:20:01')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-03-22 15:43:30')}]},
#   {'attributes': {'concept:name': 'patient 56'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-03-23 10:22:44')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-04-03 10:12:54')}]},
#   {'attributes': {'concept:name': 'patient 65'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-04-04 17:27:35')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-04-11 08:57:53')}]},
#   {'attributes': {'concept:name': 'patient 68'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-04-06 13:00:35')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-04-13 10:23:00')}]},
#   {'attributes': {'concept:name': 'patient 86'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-02 12:31:11')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-12 10:35:21')}]},
#   {'attributes': {'concept:name': 'patient 88'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-04 16:00:47')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-10 12:48:31')}]},
#   {'attributes': {'concept:name': 'patient 92'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-09 16:07:10')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-22 15:37:59')}]},
#   {'attributes': {'concept:name': 'patient 93'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-10 16:26:26')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-05-22 09:33:48')}]}],
#  (' First consult',
#   ' Blood test',
#   ' X-ray scan',
#   ' Physical test',
#   ' Second consult',
#   ' Medicine',
#   ' Final consult'): [{'attributes': {'concept:name': 'patient 3'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-01-05 16:10:58')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-01-17 13:17:06')}]},
#   {'attributes': {'concept:name': 'patient 12'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-01-20 11:43:38')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-01-27 11:18:57')}]},
#   {'attributes': {'concept:name': 'patient 14'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-01-25 13:13:36')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-02-02 10:52:11')}]},
#   {'attributes': {'concept:name': 'patient 19'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-01-31 11:39:22')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-02-10 09:34:06')}]},
#   {'attributes': {'concept:name': 'patient 38'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-02-24 10:04:44')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-03-07 10:52:38')}]},
#   {'attributes': {'concept:name': 'patient 39'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-02-27 13:18:06')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-03
}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-12 13:24:42')}]}],
#  (' First consult',
#   ' Blood test',
#   ' Physical test',
#   ' Second consult',
#   ' Medicine',
#   ' Final consult'): [{'attributes': {'concept:name': 'patient 29'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-02-13 16:54:28')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-02-22 11:42:21')}]},
#   {'attributes': {'concept:name': 'patient 35'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-02-20 17:09:45')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-02-23 14:36:45')}]},
#   {'attributes': {'concept:name': 'patient 42'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-03-02 11:06:48')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-03-09 15:57:09')}]}],
#  (' First consult',
#   ' X-ray scan',
#   ' Physical test',
#   ' Blood test',
#   ' Second consult',
#   ' Surgery',
#   ' Final consult'): [{'attributes': {'concept:name': 'patient 62'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Bob', 'time:timestamp': Timestamp('2017-03-30 15:19:58')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-04-12 15:21:36')}]},
#   {'attributes': {'concept:name': 'patient 98'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-17 10:56:48')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-05-31 14:16:13')}]}],
#  (' First consult',
#   ' Blood test',
#   ' Physical test',
#   ' X-ray scan',
#   ' Second consult',
#   ' Surgery',
#   ' Final consult'): [{'attributes': {'concept:name': 'patient 64'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-04-03 15:58:35')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-04-20 10:09:25')}]},
#   {'attributes': {'concept:name': 'patient 87'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-04 10:56:40')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-05-19 16:11:27')}]},
#   {'attributes': {'concept:name': 'patient 94'}, 'events': [{'concept:name': ' First consult', 'org:resource': ' Dr. Anna', 'time:timestamp': Timestamp('2017-05-12 12:50:53')}, '..', {'concept:name': ' Final consult', 'org:resource': ' Dr. Ben', 'time:timestamp': Timestamp('2017-05-29 09:11:38')}]}]}

# %%
# activities
activities = pm4py.get_event_attribute_values(log, "concept:name")
print(activities)
# Out:
# {' First consult': 100, ' Blood test': 100, ' Physical test': 100, ' Second consult': 100, ' Surgery': 20, ' Final consult': 100, ' X-ray scan': 90, ' Medicine': 80}

# %%
# resources
resources = pm4py.get_event_attribute_values(log, "org:resource")
print(resources)
# Out:
# {' Dr. Anna': 158, ' Lab': 100, ' Nurse Jesse': 57, ' Dr. Charlie': 5, ' Dr. Ben': 50, ' Team 1': 40, ' Pharmacy': 80, ' Team 2': 50, ' Nurse Corey': 43, ' Dr. Bob': 92, ' Dr. Rudy': 7, ' Dr. Alex': 5, ' Dr. Quinn': 3}

# %%
# dotted chart visualization
pm4py.view_dotted_chart(log)

# %%
# traces with activities carried out multiple times
rework = pm4py.get_rework_cases_per_activity(log)
rework
# Out:
# {}

# %% [markdown]
# ### Footprint Analysis

# %%
# footprint analysis
fp_log = footprints_discovery.apply(log, variant=footprints_discovery.Variants.ENTIRE_EVENT_LOG)

# %%
fp_log
# Out:
# {'dfg': Counter({(' Second consult', ' Medicine'): 80,
#           (' Medicine', ' Final consult'): 80,
#           (' First consult', ' Blood test'): 40,
#           (' Physical test', ' Second consult'): 36,
#           (' Blood test', ' Physical test'): 35,
#           (' First consult', ' Physical test'): 33,
#           (' Physical test', ' Blood test'): 33,
#           (' Blood test', ' Second consult'): 33,
#           (' Blood test', ' X-ray scan'): 32,
#           (' X-ray scan', ' Physical test'): 32,
#           (' X-ray scan', ' Second consult'): 31,
#           (' Physical test', ' X-ray scan'): 31,
#           (' X-ray scan', ' Blood test'): 27,
#           (' First consult', ' X-ray scan'): 27,
#           (' Second consult', ' Surgery'): 20,
#           (' Surgery', ' Final consult'): 20}),
#  'sequence': {(' Blood test', ' Second consult'),
#   (' First consult', ' Blood test'),
#   (' First consult', ' Physical test'),
#   (' First consult', ' X-ray scan'),
#   (' Medicine', ' Final consult'),
#   (' Physical test', ' Second consult'),
#   (' Second consult', ' Medicine'),
#   (' Second consult', ' Surgery'),
#   (' Surgery', ' Final consult'),
#   (' X-ray scan', ' Second consult')},
#  'parallel': {(' Blood test', ' Physical test'),
#   (' Blood test', ' X-ray scan'),
#   (' Physical test', ' Blood test'),
#   (' Physical test', ' X-ray scan'),
#   (' X-ray scan', ' Blood test'),
#   (' X-ray scan', ' Physical test')},
#  'start_activities': {' First consult'},
#  'end_activities': {' Final consult'},
#  'activities': {' Blood test',
#   ' Final consult',
#   ' First consult',
#   ' Medicine',
#   ' Physical test',
#   ' Second consult',
#   ' Surgery',
#   ' X-ray scan'},
#  'min_trace_length': 6}

# %% [markdown]
# ### Occurences of binary relations

# %%
fp_log['dfg']
# Out:
# Counter({(' Second consult', ' Medicine'): 80,
#          (' Medicine', ' Final consult'): 80,
#          (' First consult', ' Blood test'): 40,
#          (' Physical test', ' Second consult'): 36,
#          (' Blood test', ' Physical test'): 35,
#          (' First consult', ' Physical test'): 33,
#          (' Physical test', ' Blood test'): 33,
#          (' Blood test', ' Second consult'): 33,
#          (' Blood test', ' X-ray scan'): 32,
#          (' X-ray scan', ' Physical test'): 32,
#          (' X-ray scan', ' Second consult'): 31,
#          (' Physical test', ' X-ray scan'): 31,
#          (' X-ray scan', ' Blood test'): 27,
#          (' First consult', ' X-ray scan'): 27,
#          (' Second consult', ' Surgery'): 20,
#          (' Surgery', ' Final consult'): 20})

# %% [markdown]
# ### Causalities

# %%
fp_log['sequence']
# Out:
# {(' Blood test', ' Second consult'),
#  (' First consult', ' Blood test'),
#  (' First consult', ' Physical test'),
#  (' First consult', ' X-ray scan'),
#  (' Medicine', ' Final consult'),
#  (' Physical test', ' Second consult'),
#  (' Second consult', ' Medicine'),
#  (' Second consult', ' Surgery'),
#  (' Surgery', ' Final consult'),
#  (' X-ray scan', ' Second consult')}

# %% [markdown]
# ### Parallel

# %%
fp_log['parallel']
# Out:
# {(' Blood test', ' Physical test'),
#  (' Blood test', ' X-ray scan'),
#  (' Physical test', ' Blood test'),
#  (' Physical test', ' X-ray scan'),
#  (' X-ray scan', ' Blood test'),
#  (' X-ray scan', ' Physical test')}

# %% [markdown]
# ## Footprint table

# %%
# caution: arrows mean "causality" here NOT "follows"
gviz = fp_visualizer.apply(fp_log)
fp_visualizer.view(gviz)

# %% [markdown]
# ### Directly-follows graph

# %%
#Create graph from log (annotated with frequency)
dfg = dfg_discovery.apply(log)

# viz
gviz = dfg_visualization.apply(dfg, log=log, variant=dfg_visualization.Variants.FREQUENCY)
dfg_visualization.view(gviz)

# %%
pm4py.vis.view_dfg(dfg, log_start, end_activities)

# %%
# creatig the graph from log (annotated with time)
dfg = dfg_discovery.apply(eventlog, variant=dfg_discovery.Variants.PERFORMANCE)

# viz
gviz = dfg_visualization.apply(dfg, log=eventlog, variant=dfg_visualization.Variants.PERFORMANCE)
dfg_visualization.view(gviz)
