# %% [markdown]
# # Data Engineering 1: Graded Lab 02
# ---------------

# %% [markdown]
# # Grading
# For this graded lab you can get a total of 20 points. These 20 points count 10% of your final grade for the course.
#
# #### Start
# Start of the Graded Lab 02 is **Wednesday, May 04th at 23:55**.
#
# #### Deadline
# Deadline for the submission of the Graded Lab 02 is **Wednesday, May 19th at 23:59**.
#
# #### Note
# Check each result carefully. Use data filter, cleaning, and transformation methods wherever needed. The data can sometimes be really messy and have hidden issues.
#
# #### Submission
# You are allowed to submit the solution in groups of **two or three** students.
# Submit your GradedLab02.ipynb file renamed to `FirstnameStudent01LastnameStudent01_FirstnameStudent02LastnameStudent02_FirstnameStudent03LastnameStudent03.ipynb` in moodle.
# Please submit a runnable python jupyter notebook file.
# All other submissions will be rejected and graded with 0 points.

# %% [markdown]
# #### Task 01: Data Engineering with MongoDB [8 points].
# The 'restaurants_mongodb.json' file contains a dataset with a collection of restaurant information. In this task we work with this data and the MongoDB database. Run a MongoDB community server (see here https://www.mongodb.com/try/download/community) on your machine and connect to it with the python library 'pymongo'. It is also allowed to formulate and run the queries by using a MongoDB GUI. If you choose this option just copy and paste the queries into the cell (c) below.

# %% [markdown]
# ##### __(a)  Create a database called data and a collection called restaurants in the database data.__

# %%
# !pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in /Users/schiba/anaconda3/envs/zhaw-jupiter/lib/python3.11/site-packages (4.7.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/schiba/anaconda3/envs/zhaw-jupiter/lib/python3.11/site-packages (from pymongo[srv]) (2.6.1)

# %%
# Type your code here or use a MongoDB GUI.
from pymongo import MongoClient
CONNECTION_STRING = "mongodb://localhost:27017"

client = MongoClient(CONNECTION_STRING)
db = client['data']
collection = db['restaurants']

# %% [markdown]
# ##### __(b)  Insert the documents from the file 'restaurants.json' into the collection restaurants.__

# %%
# Type your code here or use a MongoDB GUI.
import json

restaurants = []

with open('restaurants_mongodb.json') as file:
    lines = file.readlines()
    for line in lines:
        restaurants.append(json.loads(line))

collection.insert_many(restaurants)
# Out:
# InsertManyResult([ObjectId('6633564b13eb2115043f28ca'), ObjectId('6633564b13eb2115043f28cb'), ObjectId('6633564b13eb2115043f28cc'), ObjectId('6633564b13eb2115043f28cd'), ObjectId('6633564b13eb2115043f28ce'), ObjectId('6633564b13eb2115043f28cf'), ObjectId('6633564b13eb2115043f28d0'), ObjectId('6633564b13eb2115043f28d1'), ObjectId('6633564b13eb2115043f28d2'), ObjectId('6633564b13eb2115043f28d3'), ObjectId('6633564b13eb2115043f28d4'), ObjectId('6633564b13eb2115043f28d5'), ObjectId('6633564b13eb2115043f28d6'), ObjectId('6633564b13eb2115043f28d7'), ObjectId('6633564b13eb2115043f28d8'), ObjectId('6633564b13eb2115043f28d9'), ObjectId('6633564b13eb2115043f28da'), ObjectId('6633564b13eb2115043f28db'), ObjectId('6633564b13eb2115043f28dc'), ObjectId('6633564b13eb2115043f28dd'), ObjectId('6633564b13eb2115043f28de'), ObjectId('6633564b13eb2115043f28df'), ObjectId('6633564b13eb2115043f28e0'), ObjectId('6633564b13eb2115043f28e1'), ObjectId('6633564b13eb2115043f28e2'), ObjectId('6633564b13eb2115043f28e3'), ObjectId('6633564b13eb2115043f28e4'), ObjectId('6633564b13eb2115043f28e5'), ObjectId('6633564b13eb2115043f28e6'), ObjectId('6633564b13eb2115043f28e7'), ObjectId('6633564b13eb2115043f28e8'), ObjectId('6633564b13eb2115043f28e9'), ObjectId('6633564b13eb2115043f28ea'), ObjectId('6633564b13eb2115043f28eb'), ObjectId('6633564b13eb2115043f28ec'), ObjectId('6633564b13eb2115043f28ed'), ObjectId('6633564b13eb2115043f28ee'), ObjectId('6633564b13eb2115043f28ef'), ObjectId('6633564b13eb2115043f28f0'), ObjectId('6633564b13eb2115043f28f1'), ObjectId('6633564b13eb2115043f28f2'), ObjectId('6633564b13eb2115043f28f3'), ObjectId('6633564b13eb2115043f28f4'), ObjectId('6633564b13eb2115043f28f5'), ObjectId('6633564b13eb2115043f28f6'), ObjectId('6633564b13eb2115043f28f7'), ObjectId('6633564b13eb2115043f28f8'), ObjectId('6633564b13eb2115043f28f9'), ObjectId('6633564b13eb2115043f28fa'), ObjectId('6633564b13eb2115043f28fb'), ObjectId('6633564b13eb2115043f28fc'), ObjectId('6633564b13eb2115043f28fd'), ObjectId('6633564b13eb2115043f28fe'), ObjectId('6633564b13eb2115043f28ff'), ObjectId('6633564b13eb2115043f2900'), ObjectId('6633564b13eb2115043f2901'), ObjectId('6633564b13eb2115043f2902'), ObjectId('6633564b13eb2115043f2903'), ObjectId('6633564b13eb2115043f2904'), ObjectId('6633564b13eb2115043f2905'), ObjectId('6633564b13eb2115043f2906'), ObjectId('6633564b13eb2115043f2907'), ObjectId('6633564b13eb2115043f2908'), ObjectId('6633564b13eb2115043f2909'), ObjectId('6633564b13eb2115043f290a'), ObjectId('6633564b13eb2115043f290b'), ObjectId('6633564b13eb2115043f290c'), ObjectId('6633564b13eb2115043f290d'), ObjectId('6633564b13eb2115043f290e'), ObjectId('6633564b13eb2115043f290f'), ObjectId('6633564b13eb2115043f2910'), ObjectId('6633564b13eb2115043f2911'), ObjectId('6633564b13eb2115043f2912'), ObjectId('6633564b13eb2115043f2913'), ObjectId('6633564b13eb2115043f2914'), ObjectId('6633564b13eb2115043f2915'), ObjectId('6633564b13eb2115043f2916'), ObjectId('6633564b13eb2115043f2917'), ObjectId('6633564b13eb2115043f2918'), ObjectId('6633564b13eb2115043f2919'), ObjectId('6633564b13eb2115043f291a'), ObjectId('6633564b13eb2115043f291b'), ObjectId('6633564b13eb2115043f291c'), ObjectId('6633564b13eb2115043f291d'), ObjectId('6633564b13eb2115043f291e'), ObjectId('6633564b13eb2115043f291f'), ObjectId('6633564b13eb2115043f2920'), ObjectId('6633564b13eb2115043f2921'), ObjectId('6633564b13eb2115043f2922'), ObjectId('6633564b13eb2115043f2923'), ObjectId('6633564b13eb2115043f2924'), ObjectId('6633564b13eb2115043f2925'), ObjectId('6633564b13eb2115043f2926'), ObjectId('6633564b13eb2115043f2927'), ObjectId('6633564b13eb2115043f2928'), ObjectId('6633564b13eb2115043f2929'), ObjectId('6633564b13eb2115043f292a'), ObjectId('6633564b13eb2115043f292b'), ObjectId('6633564b13eb2115043f292c'), ObjectId('6633564b13eb2115043f292d'), ObjectId('6633564b13eb2115043f292e'), ObjectId('6633564b13eb2115043f292f'), ObjectId('6633564b13eb2115043f2930'), ObjectId('6633564b13eb2115043f2931'), ObjectId('6633564b13eb2115043f ...

# %%
# Clear DB
# collection.delete_many({})
# Out:
# DeleteResult({'n': 50718, 'ok': 1.0}, acknowledged=True)

# %% [markdown]
# ##### (c)  Write the queries to print the requested results.
#
# * (1) write the query to print the total number of documents in the collection 'restaurants'
# * (2) write the query to print 5 restaurant names with 'Bronx' as borough from the collection 'restaurants'
# * (3) Write the query to print the restaurant names that achieved a score, more than 80 but less than 100 from the collection 'restaurants'
# * (4) Write the query to print the restaurant names for those restaurants which contain 'Wil' as first three letters in its name.
# * (5) Write the query to print the restaurant names which are not belonging to the borough Staten Island or Queens or Bronx or Brooklyn.
# * (6) Write the query to print each borough and the number of restaurants for each borough (hint: use the grouping function)
# * (7) Write the query to print the restaurant names which have the term 'Mexican' in the name attribute but don't have mexican as content in the cuisine attribute.
# * (8) Write the query to print all names of bakeries with 'sugar' in the name.

# %%
# Option 1: type your code here

# 1
print(f"(1): {collection.count_documents({})}")
# Out:
# (1): 25359

# %%
# 2
cursor = collection.find({'borough': 'Bronx'}, {'name': 1, '_id': 0}).limit(5)
names = ', '.join([f'\'{doc["name"]}\'' for doc in cursor])
print(f"(2): {names}")
# Out:
# (2): 'Morris Park Bake Shop', 'Wild Asia', 'Carvel Ice Cream', 'Happy Garden', 'Happy Garden'

# %%
# 3
cursor = collection.find({"grades.score": {'$gt': 80, '$lte': 100}})
names = ', '.join([f'\'{doc["name"]}\'' for doc in cursor])
print(f"(3): {names}")
# Out:
# (3): 'Murals On 54/Randolphs'S', 'Gandhi', 'Bella Napoli', 'West 79Th Street Boat Basin Cafe', 'Spicy Shallot', 'Bistro Caterers', 'Concrete Restaurant', 'Anella', 'Baluchi'S Indian Food', 'Cafe R', 'D & Y Restaurant', 'La Potencia Restaurant'

# %%
# 4
cursor = collection.find({"name": {"$regex": "^Wil.+"}})
names = ', '.join([f'\'{doc["name"]}\'' for doc in cursor])
print(f"(4): {names}")
# Out:
# (4): 'Wilken'S Fine Food', 'Wild Asia', 'Wilbel Pizza', 'Wild Edibles', 'Wild Bagels', 'Willie'S Steak House', 'Willburg Cafe', 'Willis North America', 'William Greenberg Jr Desserts', 'Wild Ginger Vegan Cafe', 'Wilfie & Nell', 'Wild Ginger Vegetarian Kitchen', 'Wild', 'William Barnacle', 'William Hallet', 'Williams & Bailey', 'Wild Ginger', 'William Greenberg Dessert', 'Williamsburg Pizza', 'Wild Cherry', 'Wilmer Hale', 'Willow Road', 'Wilma Jean', 'Williamsburg Cinemas', 'Williams Burgers', 'Williamsburg Creamery', 'Williamsburg Pizza', 'Williamsbridge Diner', 'Wild Orchid Bar & Lounge', 'Willie O'S', 'Wild Ginger'

# %%
# 5
cursor = collection.find({"borough": {"$nin": ["Staten Island", "Queens", "Bronx", "Brooklyn"]}})
names = ', '.join([f'\'{doc["name"]}\'' for doc in cursor if doc["name"] != ""])
print(f"(5): {names}")
# Out:
# (5): 'Dj Reynolds Pub And Restaurant', '1 East 66Th Street Kitchen', 'Glorious Food', 'Bully'S Deli', 'Harriet'S Kitchen', 'P & S Deli Grocery', 'Angelika Film Center', 'The Country Cafe', 'Downtown Deli', 'Olive'S', 'Cafe Metro', 'Lexler Deli', 'Lorenzo & Maria'S', 'Domino'S Pizza', 'Berkely', 'Domino'S Pizza', 'Spoon Bread Catering', 'Texas Rotisserie', 'Metropolitan Club', 'Palm Restaurant', '21 Club', 'Isle Of Capri Resturant', 'Old Town Bar & Restaurant', 'Seville Restaurant', 'Criminal Court Bldg Cafeteria', 'Nyac Main Dining Room', '7B Bar', 'Cafe Atelier (Art Students League)', 'Donohue'S Steak House', 'Tout Va Bien', 'Marchis Restaurant', 'Dining Room', 'Old Homestead', 'Serendipity 3', 'White Horse Tavern', 'Mcsorley'S Old Ale House', 'Forlinis Restaurant', 'Corner Bistro', 'Dorrian'S Red Hand Restaurant', 'La Grenouille', 'Como Pizza', 'Keats Restaurant', 'Angelo Of Mulberry St.', 'Panchito'S', 'The Princeton Club', 'Arturo'S', 'Le Perigord', 'Reynold'S Bar', 'Spain Restaurant & Bar', 'Donut Pub', 'Moran'S Chelsea', 'V & T Restaurant', 'La Parisienne Diner', 'Joe Allen Restaurant', 'Il Vagabondo Restaurant', 'Barbetta Restaurant', 'Patsy'S Italian Restaurant', 'Neary'S Pub', 'New York Pizza Suprema', 'Mee Sum Coffee Shop', 'Hop Kee Restaurant', 'Nancy Whiskey Pub', 'Nanni Restaurant', 'Killarney Rose', 'Blarney Rock', 'Dangerfield'S Night Club', 'Desmond'S Tavern', 'Tio Pepe', 'Blarney Stone', 'The Riviera Cafe', 'Baby Bo'S Burritos', 'Shun Lee Palace Restaurant', 'El Charro Espanol', 'Finnegan'S Wake', 'Mexico Lindo Restaurant', 'Twins Pub', 'Broome Street Bar', 'Jg Melon Restaurant', 'Emerald Pub', 'Tap Room', 'Cocktail Room (Nyac)', 'Flame Restaurant Coffee House', 'Jackson Hole', 'John'S Restaurant', 'Grassroot Tavern', 'Mr Broadway Kosher Restaurant', 'Malaga Restaurant', 'Capitol Restaurant', 'La Bonne Soupe Bistro', 'Mimis Restaurant & Bar', 'Griffis Faculty Club', 'Gray'S Papaya', 'One If By Land Two If By Sea', 'Fiorellos', 'Ford Foundation Cafeteria', 'Elephant & Castle', 'Oyster Bar', 'Cherry Tavern', 'Red Flame Diner', 'Maggies Place', 'Brady'S Bar', 'Da Silvano Restaurant', 'Benjamin', 'Jimmy'S Corner', 'Sammy'S Steakhouse', 'Il Cortile Restaurant', 'Maries Crisis Cafe', 'Boots & Saddle Bar', 'Cafe Riazor', 'Raouls', 'The Brook', 'Hatsuhana Restaurant', 'La Mangeoire', 'Viand Coffee Shop', 'Palm Too', 'Nada-Sushi', 'Pergola Des Artistes', 'Reif'S Tavern', 'White Horse Tavern', 'Caffe Reggio', 'Cafe Un Deux Trois', 'Dan Tempura', 'Knickerbocker Bar & Grill', 'El Pote Espanol', 'Mudville Saloon', 'Viand Cafe', 'Nectar Coffee Shop', 'The Cupping Room', 'Pete'S Tavern', 'Jim Brady'S Restaurant', 'Villa Mosconi Restaurant', 'Reme Restaurant', 'The New Amity Restaurant', 'Volare Restaurant', 'Sparks Steak House', 'Mcdonald'S', 'Ear Inn', 'Mughlai Restaurant', 'Rossini'S', 'Three Guy'S Restaurant', 'Cucina Vivolo', 'The Players Club', 'Cafe Espanol', 'Smith & Wollensky', 'Olive Tree Cafe & Comedy Cellar', 'Tokubei 86', 'Coliseum Bar Restaurant', 'Mariella Pizza', 'West Bank Cafe', 'The Four Seasons', 'Zafi'S Luncheonette', 'Ty'S', 'La Ripaille Restaurant', 'Don Filippo Restaurant', 'Murals On 54/Randolphs'S', 'Caruso Pizza #2', 'Shabu-Shabu 70 Restaurant', 'The Greek Corner', 'Racquet & Tennis Club', 'Astro Restaurant', 'Caffe Dante', 'Souen Restaurant', 'Villa Berulia', 'Victor'S Cafe', 'Keens Steakhouse', 'Bar 515', 'Il Mulino', 'Felidia Restaurant', 'The Malt House', 'Shun Lee', 'Pongsri Thai Restaurant', 'Primavera Pizza & Pasta', 'Elio'S', 'Kasteli Ii', 'Molly Wee Pub', 'La Mediterranee Restaurant', 'Omen Japanese Cuisine', 'Bar Vetro', 'Rosie O'Grady Restaurant', 'Casa Bella', 'Raccoon Lodge', 'Chez Napolean', 'Agra Restaurant', 'Lindy'S', 'Arturo'S', 'Paris Blues', 'Gene'S Resturant', 'Cozy Soup & Burger', 'Candle Bar', 'Tevere 84', 'Haagen-Dazs', 'Charlie'S Mom Chinese Restaurant', 'Lusardi'S Restaurant', 'Blue Note Jazz', 'The Water Club', 'Manhattan Monster', 'American Museum Of Natural History Food  ...

# %%
# 6
pipeline = [{"$group": {"_id": "$borough", "count": {"$count": {}}}}]
cursor = collection.aggregate(pipeline)
print(f"(6): ")
for doc in cursor:
    print(f'Borough: {doc["_id"]}; Count: {doc["count"]}')
# Out:
# (6):
# Borough: Missing; Count: 51
# Borough: Brooklyn; Count: 6086
# Borough: Manhattan; Count: 10259
# Borough: Bronx; Count: 2338
# Borough: Queens; Count: 5656
# Borough: Staten Island; Count: 969

# %%
# 7
cursor = collection.find({"cuisine": {"$ne": "Mexican"}, "name": {"$regex": "Mexican", "$options": "i"}})
names = ', '.join([f'\'{doc["name"]}\'' for doc in cursor])
print(f"(7): {names}")
# Out:
# (7): 'El Azteca Mexican Restaurant', 'Chipotle Mexican Grill', 'Chipotle Mexican Grill', 'Chipotle Mexican Grill', 'Chipotle Mexican Grill', 'Chipotle Mexican Grill', 'Chipotle Mexican Grill', 'El Bravo Mexican Bar & Restaurant', 'La Parranda Mexicana Bar & Restaurant', 'Venga Fresh Mexican Grill', 'Chipotle Mexican Grill', 'Tong Xing Chinese Restaurant & New Taco Mexican', 'Chipotle Mexican Grill #1394', 'Cantina Mexicana', 'El Acatlan Mexican Restaurant', 'Au Bon Pain/ Andale Mexican Grill (Bxcc)', 'Qdoba Mexican Grill', 'El Mexicano Restaurante & Cafe', 'Pancho'S Antojitos Mexicanos', 'Chipotle Mexican Grill', 'Chipotle Mexican Grill #1968', 'Chipotle Mexican Grill', 'Diegos Mexican Grill', 'Chipotle Mexican Grill #221', 'Agave Mexican & American Grill', 'Cueva De Lobos Mexican Restaurant', 'Lupita'S Mexican Food', 'Chipotle Mexican Grill # 2135', '7 Tacos Mexican Cuisine Corp', 'Juquila Mexican Cuisine ', 'Selena Rosa Mexicana', 'Mexican Restaurant Bar', 'Mallenche Mexican Grill', 'Sandy Deli & Mexican Grill'

# %%
# 8
cursor = collection.find({"cuisine": "Bakery", "name": {"$regex": "sugar", "$options": "i"}})
names = ', '.join([f'\'{doc["name"]}\'' for doc in cursor])
print(f"(8): {names}")
# Out:
# (8): 'Sugar Bun Bakery', 'Sugar City Bakery', 'Sugar Sweet Sunshine', 'Sugar Couture'

# %% [markdown]
# #### Task 02:  Data Engineering with  BaseX [8 points].
# Install the BaseX XML database and create a database with the file 'restaurants_basex.json'. Formulate all queries from the Task 01 (1) to (8) with XPath/XQuery in BaseX. The content of both json files is the same, so you should retrieve the same results as with the MongoDB solution. You can execute the queries directly in the BaseX GUI. After succesful execution in BaseX just copy and paste the queries into the cell below. If a query is not expressible in XPath/XQuery write down not possible and the reason.

# %% [markdown]
# Answer...
#
# (1)
# ```
# let $restaurants := (doc("restaurants_basex.json")/json/_)
#
# return <results>
#   <count>{count($restaurants)}</count>
# </results>
# ```
# (2)
# ```
#
# ```
#
# (3)
# ```
#
# ```
#
# (4)
# ```
#
# ```
#
# (5)
# ```
#
# ```
#
# (6)
# ```
#
# ```
#
# (7)
# ```
#
# ```
#
# (8)
# ```
#
# ```

# %% [markdown]
# #### Task 03: Conclusions [4 points].
# Write 5-10 sentences with your conclusions concerning performance, usability etc. between using MongoDB and BaseX.

# %% [markdown]
# Answer...
#
# Einige resultate erfordern Domänen wissen, um die Daten zu bereinigen.
